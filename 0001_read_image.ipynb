# %%
import cv2
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
img = cv2.imread("20220227-A7401455_TP_V4.jpg")

# %%
#cv2.imshow("window", img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
img_r = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(1, (12., 12.))
plt.imshow(img_r)
