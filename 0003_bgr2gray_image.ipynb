# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("20220227-A7401455_TP_V4.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7F32B64B5C50>

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=800x533 at 0x7F32B6463510>
