# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("20220227-A7401455_TP_V4.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7FDF3D53F150>

# %%
flip_img = cv2.flip(img, 0)

# %%
cv2_imshow(flip_img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7FDF3D4C0910>

# %%
flip_img = cv2.flip(img,1)

# %%
cv2_imshow(flip_img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x533 at 0x7FDF3D4C1490>
